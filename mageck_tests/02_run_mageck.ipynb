# %%
from process_helper import get_mageck_command

# %% [markdown]
# # Intalación Mageck
#
# "Reads were aligned to the appropriate reference library using MAGeCK version 0.5.9.2"
# ```bash
# conda install -c bioconda mageck=0.5.9.2
# ```

# %%
# For CD4 supplemental
CRISPR_type = 'CRISPRa'
cell_types = 'CD4'
cytokine = 'TNFa'
study_type = 'supplemental'
input_folder = 'input_data'
count_filename = f'{input_folder}/{CRISPR_type}.{cell_types}_count.{study_type}.txt'
nt_filename = f'{input_folder}/{CRISPR_type}.{cell_types}_NO-TARGET.{study_type}.txt'
out_filename = f'data_out/{CRISPR_type}.{cytokine}.{cell_types}.{study_type}'
donor_1 = 15
donor_2 = 16
mageck_command = get_mageck_command(
    count_filename,
    donor_1,
    donor_2,
    cytokine,
    out_filename,
    nt_filename
)

# %%
! {mageck_command}
# Out:
# INFO  @ Wed, 09 Oct 2024 18:02:12: Parameters: /home/julian/miniconda3/envs/mageckenv2/bin/mageck test -k input_data/CRISPRa.CD4_count.supplemental.txt -t Donor15_TNFa_high,Donor16_TNFa_high -c Donor15_TNFa_low,Donor16_TNFa_low -n data_out/CRISPRa.TNFa.CD4.supplemental --norm-method none --paired --control-sgrna input_data/CRISPRa.CD4_NO-TARGET.supplemental.txt --keep-tmp
# INFO  @ Wed, 09 Oct 2024 18:02:12: Welcome to MAGeCK v0.5.9.2. Command: test
# INFO  @ Wed, 09 Oct 2024 18:02:12: Loading count table from input_data/CRISPRa.CD4_count.supplemental.txt
# INFO  @ Wed, 09 Oct 2024 18:02:12: Processing 1 lines..
# INFO  @ Wed, 09 Oct 2024 18:02:13: Processing 100001 lines..
# INFO  @ Wed, 09 Oct 2024 18:02:13: Loaded 113238 records.
# INFO  @ Wed, 09 Oct 2024 18:02:13: Loading R template file: /home/julian/miniconda3/envs/mageckenv2/lib/python3.7/site-packages/mageck/plot_template.RTemplate.
# ...

# %%
# For CD8 
CRISPR_type = 'CRISPRa'
cell_types = 'CD8'
cytokine = 'IFNG'
study_type = 'orig'
input_folder = 'input_data'
count_filename = f'{input_folder}/{CRISPR_type}.{cell_types}_count.{study_type}.txt'
nt_filename = f'{input_folder}/{CRISPR_type}.{cell_types}_NO-TARGET.{study_type}.txt'
out_filename = f'data_out/{CRISPR_type}.{cytokine}.{cell_types}.{study_type}'
donor_1 = 1
donor_2 = 2
mageck_command = get_mageck_command(
    count_filename,
    donor_1,
    donor_2,
    cytokine,
    out_filename,
    nt_filename
)

# %%
! {mageck_command}
# Out:
# INFO  @ Wed, 09 Oct 2024 18:03:55: Parameters: /home/julian/miniconda3/envs/mageckenv2/bin/mageck test -k input_data/CRISPRa.CD8_count.orig.txt -t Donor1_IFNG_high,Donor2_IFNG_high -c Donor1_IFNG_low,Donor2_IFNG_low -n data_out/CRISPRa.IFNG.CD8.orig --norm-method none --paired --control-sgrna input_data/CRISPRa.CD8_NO-TARGET.orig.txt --keep-tmp
# INFO  @ Wed, 09 Oct 2024 18:03:55: Welcome to MAGeCK v0.5.9.2. Command: test
# INFO  @ Wed, 09 Oct 2024 18:03:55: Loading count table from input_data/CRISPRa.CD8_count.orig.txt
# INFO  @ Wed, 09 Oct 2024 18:03:55: Processing 1 lines..
# INFO  @ Wed, 09 Oct 2024 18:03:55: Processing 100001 lines..
# INFO  @ Wed, 09 Oct 2024 18:03:55: Loaded 113238 records.
# INFO  @ Wed, 09 Oct 2024 18:03:55: Loading R template file: /home/julian/miniconda3/envs/mageckenv2/lib/python3.7/site-packages/mageck/plot_template.RTemplate.
# ...

# %%
CRISPR_type = 'CRISPRa'
cell_types = 'CD4'
cytokine = 'IFNG'
study_type = 'supplemental'
input_folder = 'input_data'
count_filename = f'{input_folder}/{CRISPR_type}.{cell_types}_count.{study_type}.txt'
nt_filename = f'{input_folder}/{CRISPR_type}.{cell_types}_NO-TARGET.{study_type}.txt'
out_filename = f'data_out/{CRISPR_type}.{cytokine}.{cell_types}.{study_type}'
donor_1 = 15
donor_2 = 16
mageck_command = get_mageck_command(
    count_filename,
    donor_1,
    donor_2,
    cytokine,
    out_filename,
    nt_filename
)

# %%
! {mageck_command}
# Out:
# INFO  @ Wed, 09 Oct 2024 18:23:41: Parameters: /home/julian/miniconda3/envs/mageckenv2/bin/mageck test -k input_data/CRISPRa.CD4_count.supplemental.txt -t Donor15_IFNG_high,Donor16_IFNG_high -c Donor15_IFNG_low,Donor16_IFNG_low -n data_out/CRISPRa.IFNG.CD4.supplemental --norm-method none --paired --control-sgrna input_data/CRISPRa.CD4_NO-TARGET.supplemental.txt --keep-tmp
# INFO  @ Wed, 09 Oct 2024 18:23:41: Welcome to MAGeCK v0.5.9.2. Command: test
# INFO  @ Wed, 09 Oct 2024 18:23:41: Loading count table from input_data/CRISPRa.CD4_count.supplemental.txt
# INFO  @ Wed, 09 Oct 2024 18:23:41: Processing 1 lines..
# INFO  @ Wed, 09 Oct 2024 18:23:41: Processing 100001 lines..
# INFO  @ Wed, 09 Oct 2024 18:23:41: Loaded 113238 records.
# INFO  @ Wed, 09 Oct 2024 18:23:41: Loading R template file: /home/julian/miniconda3/envs/mageckenv2/lib/python3.7/site-packages/mageck/plot_template.RTemplate.
# ...
