# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from process_helper import plot_volcano, plot_donors_scatter, generate_screen_analysis_table

# %%
# screen_analysis_table = generate_screen_analysis_table()

# %%
cytokine = 'IFNG'
screen = 'CRISPRa'
cell_type = 'CD8'
study_type = 'orig'

screen_analysis_table = pd.read_csv('data_out/screen_analysis_table.csv', index_col=False).iloc[:, 1:]
screen_analysis_table = screen_analysis_table[
    (screen_analysis_table['Screen'] == screen) & 
    (screen_analysis_table['Cytokine'] == cytokine) 
].set_index('Gene')

# %%
screen_analysis_table['Hit_Type'].value_counts()
# Out:
# Hit_Type
# Negative Regulator    292
# Positive Regulator    181
# Name: count, dtype: int64

# %% [markdown]
# # TNFa Positive Regulator sorted by LFC

# %%
screen_analysis_table[screen_analysis_table['Hit_Type'] == 'Positive Regulator'].sort_values('LFC', ascending=False).head(50)
# Out:
#             Screen  Donor1_LFC  Donor2_LFC      LFC     zscore       FDR  \
# Gene
# IFNG       CRISPRa    3.518000    3.281800  3.38790  13.168175  0.000150
# CD28       CRISPRa    3.502650    2.857150  3.17580  12.363582  0.000150
# VAV1       CRISPRa    3.231700    2.617450  3.09790  12.068071  0.000150
# TNFRSF1A   CRISPRa    2.160650    2.303700  2.29110   9.007505  0.000150
# TNFRSF1B   CRISPRa    2.058700    2.240550  2.24060   8.815936  0.000150
# RELA       CRISPRa    1.399600    1.827950  1.60890   6.419605  0.000150
# IL1R1      CRISPRa    1.645650    1.267700  1.56290   6.245106  0.000150
# HELZ2      CRISPRa    1.579750    1.215250  1.48070   5.933283  0.000150
# TBX21      CRISPRa    1.377900    1.460150  1.44080   5.781924  0.000150
# LCP2       CRISPRa    1.028965    1.973400  1.42490   5.721608  0.000150
# CDKN1A     CRISPRa    1.396750    1.422750  1.42270   5.713263  0.000401
# CD2        CRISPRa    1.352100    1.564950  1.41000   5.665086  0.000150
# FOSL1      CRISPRa    1.091835    1.415200  1.38630   5.575181  0.000150
# APOL2      CRISPRa    1.717050    1.084750  1.28670   5.197352  0.000150
# LAT        CRISPRa    1.282150    1.253100  1.28220   5.180281  0.000150
# APOBEC3A   CRISPRa    1.091290    1.444850  1.28130   5.176867  0.001503
# OTUD7B     CRISPRa    0.808070    1.470700  1.28000   5.171936  0.000150
# ZC3HAV1    CRISPRa    0.525405    1.612750  1.20380   4.882874  0.001627
# TRIM21     CRISPRa    1.199950    0.979085  1.20000   4.868459  0.000150
# TRAF3IP2   CRISPRa    1.130100    1.482150  1.19400   4.845698  0.000150
# WT1        CRISPRa    1.191150    1.155400  1.18430   4.808901  0.000150
# PRDM1      CRISPRa    1.365900    1.100800  1.18130   4.797521  0.004950
# CDKN2C     CRISPRa    1.190100    1.084250  1.16260   4.726583  0.001341
# IL9R       CRISPRa    1.109950    1.439400  1.15880   4.712168  0.000150
# BICDL2     CRISPRa    1.196500    0.811420  1.14340   4.653749  0.000150
# TAGAP      CRISPRa    1.163500    1.069595  1.13310   4.614676  0.000150
# SLC16A1    CRISPRa    1.318700    0.579595  1.11850   4.559291  0.000589
# DEF6       CRISPRa    0.983360    1.460600  1.11740   4.555119  0.000589
# KIF2C      CRISPRa    0.608615    1.321350  1.11120   4.531599  0.001650
# AKAP12     CRISPRa    0.892645    1.229700  1.10610   4.512252  0.000401
# FOXQ1      CRISPRa    1.097450    1.717650  1.10310   4.500872  0.000150
# OTUD7A     CRISPRa    1.115300    0.876155  1.07460   4.392758  0.000150
# DEPDC7     CRISPRa    1.206650    0.898175  1.06820   4.368480  0.000401
# APOBEC3D   CRISPRa    0.643060    1.364100  1.06240   4.346478  0.000521
# MAP3K12    CRISPRa    0.884140    1.212300  1.05610   4.322579  0.001542
# NLRC3      CRISPRa    1.160950    0.897160  1.04420   4.277437  0.000150
# EMP1       CRISPRa    1.077310    1.010140  1.01020   4.148459  0.000150
# CD27       CRISPRa    1.132700    0.699100  0.98500   4.052864  0.000150
# CD247      CRISPRa    1.678650    0.579130  0.96909   3.992510  0.000589
# FOXD2      CRISPRa    1.692450    0.683490  0.96237   3.967018  0.000150
# EOMES      CRISPRa    1.542850    0.595055  0.96169   3.964439  0.000150
# PIK3AP1    CRISPRa    0.884945    1.072950  0.96028   3.959090  0.000150
# GNA11      CRISPRa    0.962680    0.943755  0.94375   3.896384  0.001159
# PLCG2      CRISPRa    0.608020    0.942180  0.94218   3.890428  0.001159
# GLMN       CRISPRa    1.124000    0.375039  0.91627   3.792139  0.001650
# APOBEC3C   CRISPRa    0.640050    1.523850  0.90189   3.737589  0.001503
# PRKD2      CRISPRa    0.887740    0.955335  0.88774   3.683912  0.000150
# TNFRSF9    CRISPRa    1.015990    0.734450  0.87096   3.620258  0.000150
# TNFRSF12A  CRISPRa    0.863775    0.814470  0.86378   3.593021  0.001503
# GMFG       CRISPRa    0.039085    0.866560  0.86021   3.579478  0.015926
#
#             Hit            Hit_Type Cytokine
# Gene
# IFNG       True  Positive Regulator     IFNG
# CD28       True  Positive Regulator     IFNG
# VAV1       True  Positive Regulator     IFNG
# TNFRSF1A   True  Positive Regulator     IFNG
# TNFRSF1B   True  Positive Regulator     IFNG
# RELA       True  Positive Regulator     IFNG
# IL1R1      True  Positive Regulator     IFNG
# HELZ2      True  Positive Regulator     IFNG
# TBX21      True  Positive Regulator     IFNG
# LCP2       True  Positive Regulator     IFNG
# CDKN1A     True  Positive Regulator     IFNG
# CD2        True  Positive Regulator     IFNG
# FOSL1      True  Positive Regulator     IFNG
# APOL2      True  Positive Regulator     IFNG
# LAT        True  Positive Regulator     IFNG
# APOBEC3A   True  Positive Regulator     IFNG
# OTUD7B     True  Positive Regulator     IFNG
# ZC3HAV1    True  Positive Regulator     IFNG
# TRIM21     True  Positive Regulator     IFNG
# TRAF3IP2   True  Positive Regulator     IFNG
# WT1        True  Positive Regulator     IFNG
# PRDM1      True  Positive Regulator     IFNG
# CDKN2C     True  Positive Regulator     IFNG
# IL9R       True  Positive Regulator     IFNG
# BICDL2     True  Positive Regulator     IFNG
# TAGAP      True  Positive Regulator     IFNG
# SLC16A1    True  Positive Regulator     IFNG
# DEF6       True  Positive Regulator     IFNG
# KIF2C      True  Positive Regulator     IFNG
# AKAP12     True  Positive Regulator     IFNG
# FOXQ1      True  Positive Regulator     IFNG
# OTUD7A     True  Positive Regulator     IFNG
# DEPDC7     True  Positive Regulator     IFNG
# APOBEC3D   True  Positive Regulator     IFNG
# MAP3K12    True  Positive Regulator     IFNG
# NLRC3      True  Positive Regulator     IFNG
# EMP1       True  Positive Regulator     IFNG
# CD27       True  Positive Regulator     IFNG
# CD247      True  Positive Regulator     IFNG
# FOXD2      True  Positive Regulator     IFNG
# EOMES      True  Positive Regulator     IFNG
# PIK3AP1    True  Positive Regulator     IFNG
# GNA11      True  Positive Regulator     IFNG
# PLCG2      True  Positive Regulator     IFNG
# GLMN       True  Positive Regulator     IFNG
# APOBEC3C   True  Positive Regulator     IFNG
# PRKD2      True  Positive Regulator     IFNG
# TNFRSF9    True  Positive Regulator     IFNG
# TNFRSF12A  True  Positive Regulator     IFNG
# GMFG       True  Positive Regulator     IFNG

# %% [markdown]
# # TNFa Negative Regulator sorted by LFC

# %%
screen_analysis_table[screen_analysis_table['Hit_Type'] == 'Negative Regulator'].sort_values('LFC', ascending=True).head(50)
# Out:
#           Screen  Donor1_LFC  Donor2_LFC     LFC     zscore       FDR   Hit  \
# Gene
# MAP4K1   CRISPRa   -3.276200   -2.562450 -2.9269 -10.786781  0.000101  True
# LAT2     CRISPRa   -2.738450   -2.516500 -2.7385 -10.072093  0.000101  True
# SLA2     CRISPRa   -2.700850   -2.118350 -2.4312  -8.906362  0.000101  True
# MUC1     CRISPRa   -2.488650   -1.357150 -2.2092  -8.064213  0.000101  True
# JMJD1C   CRISPRa   -2.371600   -1.994700 -2.1556  -7.860884  0.000101  True
# FOXL2NB  CRISPRa   -2.251250   -1.853650 -2.1240  -7.741010  0.000101  True
# GRAP     CRISPRa   -2.639950   -1.747300 -2.0606  -7.500505  0.000101  True
# FOXL2    CRISPRa   -1.811350   -1.351090 -1.8113  -6.554795  0.000101  True
# EBF2     CRISPRa   -1.927100   -1.699050 -1.7668  -6.385986  0.000101  True
# IL2RB    CRISPRa   -1.836250   -1.651250 -1.7657  -6.381813  0.000101  True
# IKZF3    CRISPRa   -2.164450   -1.600400 -1.7538  -6.336671  0.000101  True
# FOXF1    CRISPRa   -1.687600   -1.807550 -1.7530  -6.333636  0.000101  True
# BTLA     CRISPRa   -1.598400   -1.696450 -1.6965  -6.119305  0.000101  True
# GATA3    CRISPRa   -1.887200   -1.444550 -1.6879  -6.086681  0.000101  True
# MUC21    CRISPRa   -1.798250   -1.200765 -1.5852  -5.697093  0.000101  True
# LAX1     CRISPRa   -2.003650   -1.048415 -1.5724  -5.648537  0.000101  True
# SETD1B   CRISPRa   -1.511800   -1.542550 -1.5426  -5.535491  0.000101  True
# CD5      CRISPRa   -1.454150   -1.497200 -1.4972  -5.363268  0.000101  True
# GATA6    CRISPRa   -1.987950   -1.212950 -1.4966  -5.360992  0.000101  True
# INPPL1   CRISPRa   -1.814300   -1.354200 -1.4880  -5.328368  0.000101  True
# CEBPB    CRISPRa   -1.660950   -1.327700 -1.4821  -5.305987  0.000427  True
# SOCS3    CRISPRa   -1.503250   -1.256400 -1.4779  -5.290054  0.000101  True
# SPN      CRISPRa   -1.353800   -1.696450 -1.4384  -5.140213  0.000101  True
# GRB2     CRISPRa   -1.655350   -1.382500 -1.4280  -5.100761  0.000101  True
# PTPRC    CRISPRa   -1.283950   -1.549350 -1.4140  -5.047652  0.000101  True
# LRRC25   CRISPRa   -1.533550   -1.184200 -1.3726  -4.890603  0.000101  True
# NFKBIA   CRISPRa   -1.065345   -1.455400 -1.3656  -4.864049  0.000101  True
# RNF19B   CRISPRa   -1.313650   -1.445800 -1.3536  -4.818527  0.000101  True
# ARHGDIB  CRISPRa   -1.145055   -1.444450 -1.3519  -4.812078  0.000101  True
# CEBPA    CRISPRa   -1.840950   -0.923425 -1.3119  -4.660340  0.004261  True
# LYN      CRISPRa   -1.232350   -1.312650 -1.2894  -4.574987  0.000101  True
# CD244    CRISPRa   -1.263500   -1.067495 -1.2635  -4.476736  0.003345  True
# XKR9     CRISPRa   -1.222190   -1.262950 -1.2630  -4.474839  0.000291  True
# CD52     CRISPRa   -1.018655   -1.414750 -1.2607  -4.466114  0.000101  True
# LAPTM5   CRISPRa   -1.251250   -1.315400 -1.2513  -4.430456  0.000101  True
# NFATC1   CRISPRa   -1.347550   -0.533525 -1.2413  -4.392521  0.000427  True
# TRIM28   CRISPRa   -1.934900   -0.847005 -1.2369  -4.375830  0.000101  True
# PTPN12   CRISPRa   -1.631600   -0.835370 -1.1886  -4.192606  0.000101  True
# LCK      CRISPRa   -0.923830   -1.263650 -1.1851  -4.179329  0.000101  True
# FOXF2    CRISPRa   -1.126860   -1.205765 -1.1850  -4.178949  0.000101  True
# SMAD9    CRISPRa   -1.144950   -0.671160 -1.1450  -4.027211  0.000977  True
# SOX13    CRISPRa   -0.919775   -1.298350 -1.1321  -3.978275  0.001014  True
# WNK4     CRISPRa   -1.244350   -1.096300 -1.1230  -3.943755  0.000101  True
# POU2AF1  CRISPRa   -1.122550   -1.035980 -1.1226  -3.942237  0.001014  True
# FOXA3    CRISPRa   -1.365700   -1.043375 -1.1172  -3.921752  0.000101  True
# B3GNT5   CRISPRa   -1.386550   -0.650765 -1.0979  -3.848539  0.000977  True
# USP10    CRISPRa   -1.099545   -1.094950 -1.0949  -3.837158  0.015637  True
# WLS      CRISPRa   -1.165050   -0.767105 -1.0909  -3.821984  0.000864  True
# POLR3K   CRISPRa   -1.150600   -1.018600 -1.0846  -3.798086  0.033641  True
# UBASH3B  CRISPRa   -1.081000   -0.916690 -1.0810  -3.784429  0.000977  True
#
#                    Hit_Type Cytokine
# Gene
# MAP4K1   Negative Regulator     IFNG
# LAT2     Negative Regulator     IFNG
# SLA2     Negative Regulator     IFNG
# MUC1     Negative Regulator     IFNG
# JMJD1C   Negative Regulator     IFNG
# FOXL2NB  Negative Regulator     IFNG
# GRAP     Negative Regulator     IFNG
# FOXL2    Negative Regulator     IFNG
# EBF2     Negative Regulator     IFNG
# IL2RB    Negative Regulator     IFNG
# IKZF3    Negative Regulator     IFNG
# FOXF1    Negative Regulator     IFNG
# BTLA     Negative Regulator     IFNG
# GATA3    Negative Regulator     IFNG
# MUC21    Negative Regulator     IFNG
# LAX1     Negative Regulator     IFNG
# SETD1B   Negative Regulator     IFNG
# CD5      Negative Regulator     IFNG
# GATA6    Negative Regulator     IFNG
# INPPL1   Negative Regulator     IFNG
# CEBPB    Negative Regulator     IFNG
# SOCS3    Negative Regulator     IFNG
# SPN      Negative Regulator     IFNG
# GRB2     Negative Regulator     IFNG
# PTPRC    Negative Regulator     IFNG
# LRRC25   Negative Regulator     IFNG
# NFKBIA   Negative Regulator     IFNG
# RNF19B   Negative Regulator     IFNG
# ARHGDIB  Negative Regulator     IFNG
# CEBPA    Negative Regulator     IFNG
# LYN      Negative Regulator     IFNG
# CD244    Negative Regulator     IFNG
# XKR9     Negative Regulator     IFNG
# CD52     Negative Regulator     IFNG
# LAPTM5   Negative Regulator     IFNG
# NFATC1   Negative Regulator     IFNG
# TRIM28   Negative Regulator     IFNG
# PTPN12   Negative Regulator     IFNG
# LCK      Negative Regulator     IFNG
# FOXF2    Negative Regulator     IFNG
# SMAD9    Negative Regulator     IFNG
# SOX13    Negative Regulator     IFNG
# WNK4     Negative Regulator     IFNG
# POU2AF1  Negative Regulator     IFNG
# FOXA3    Negative Regulator     IFNG
# B3GNT5   Negative Regulator     IFNG
# USP10    Negative Regulator     IFNG
# WLS      Negative Regulator     IFNG
# POLR3K   Negative Regulator     IFNG
# UBASH3B  Negative Regulator     IFNG

# %%
top_n = 10
top_10_low = pd.read_csv(f'data_out/{screen}.{cytokine}.{cell_type}.{study_type}.gene.low.txt', sep='\t')['group_id'][:top_n].to_list()
top_10_high = pd.read_csv(f'data_out/{screen}.{cytokine}.{cell_type}.{study_type}.gene.high.txt', sep='\t')['group_id'][:top_n].to_list()
fig_1 = plot_donors_scatter(
    screen_analysis_table,
    'Donor 15, LFC',
    'Donor 16, LFC',
    f'{cell_type}-{cytokine}'
);
# Out:
# Looks like you are using a tranform that doesn't support FancyArrowPatch, using ax.annotate instead. The arrows might strike through texts. Increasing shrinkA in arrowprops might help.

# %%
fig_2 = plot_volcano(
    screen_analysis_table,
    x_label='LFC ' + '$'+f'{cytokine}'+'^{hi}/TNFa^{low}$',
    y_label='$-Log_{10}(FDR)$',
    plot_title=f'{cell_type}-{cytokine}',
    eps=1e-6,
    top_10_low=top_10_low,
    top_10_high=top_10_high,
)
