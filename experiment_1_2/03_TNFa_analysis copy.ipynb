# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from process_helper import plot_volcano, plot_donors_scatter, generate_screen_analysis_table

# %%
# screen_analysis_table = generate_screen_analysis_table()
# Out:
# ['data_out/CRISPRa.IFNG.CD4.supplemental.gene_summary.txt', 'data_out/CRISPRa.TNFa.CD4.supplemental.gene_summary.txt', 'data_out/CRISPRa.IFNG.CD8.orig.gene_summary.txt']
# ['data_out/CRISPRa.TNFa.CD4.supplemental.sgrna_summary.txt', 'data_out/CRISPRa.IFNG.CD8.orig.sgrna_summary.txt', 'data_out/CRISPRa.IFNG.CD4.supplemental.sgrna_summary.txt']
# Both pos and neg fdr minor than 0.05
# [0, 1, 1]

# %%
# screen_analysis_table
# Out:
# Empty DataFrame
# Columns: [Screen, Donor1_LFC, Donor2_LFC, LFC, zscore, FDR, Hit, Hit_Type, Cytokine]
# Index: []

# %%
cytokine = 'TNFa'
screen = 'CRISPRa'
cell_type = 'CD4'
study_type = 'supplemental'

screen_analysis_table = pd.read_csv('data_out/screen_analysis_table.csv', index_col=False).iloc[:, 1:]
screen_analysis_table
# Out:
#        Gene   Screen  Donor1_LFC  Donor2_LFC       LFC    zscore       FDR  \
# 0      A1BG  CRISPRa    0.453000    0.471505  0.336050  2.676686  0.160467
# 1      A1BG  CRISPRa    0.371575    0.151093  0.336050  2.676686  0.160467
# 2      A1BG  CRISPRa    0.453000    0.471505  0.471510  2.104959  0.066411
# 3      A1BG  CRISPRa    0.371575    0.151093  0.471510  2.104959  0.066411
# 4      A1BG  CRISPRa    0.266305   -0.087442  0.190800  0.372649  0.965390
# ...     ...      ...         ...         ...       ...       ...       ...
# 94645  ZZZ3  CRISPRa   -0.219016    0.230555 -0.469220 -1.516846  0.528113
# 94646  ZZZ3  CRISPRa   -0.469220   -0.536920 -0.469220 -1.516846  0.528113
# 94647  ZZZ3  CRISPRa   -0.219016    0.230555  0.063556  0.557401  0.864937
# 94648  ZZZ3  CRISPRa   -0.469220   -0.536920  0.063556  0.557401  0.864937
# 94649  ZZZ3  CRISPRa   -0.361215    0.145345 -0.038584 -0.468514  0.683262
#
#          Hit Hit_Type Cytokine
# 0      False      NaN     IFNG
# 1      False      NaN     IFNG
# 2      False      NaN     IFNG
# 3      False      NaN     IFNG
# 4      False      NaN     TNFa
# ...      ...      ...      ...
# 94645  False      NaN     IFNG
# 94646  False      NaN     IFNG
# 94647  False      NaN     IFNG
# 94648  False      NaN     IFNG
# 94649  False      NaN     TNFa
#
# [94650 rows x 10 columns]

# %%
screen_analysis_table = screen_analysis_table[
    (screen_analysis_table['Screen'] == screen) & 
    (screen_analysis_table['Cytokine'] == cytokine) 
]
screen_analysis_table
# Out:
#           Gene   Screen  Donor1_LFC  Donor2_LFC       LFC    zscore       FDR  \
# 4         A1BG  CRISPRa    0.266305   -0.087442  0.190800  0.372649  0.965390
# 9         A1CF  CRISPRa    0.223835    0.189680  0.223830  0.493771  1.000000
# 14         A2M  CRISPRa    0.177685    0.204170  0.177690  0.324574  0.758835
# 19       A2ML1  CRISPRa   -0.084406    0.017370 -0.078052 -0.613245  0.645506
# 24     A3GALT2  CRISPRa   -0.060033    0.251070  0.112140  0.084199  0.623199
# ...        ...      ...         ...         ...       ...       ...       ...
# 94629   ZYG11A  CRISPRa   -0.057830    0.116976  0.077883 -0.041424  0.787891
# 94634   ZYG11B  CRISPRa    0.148973    0.401131  0.148970  0.219256  0.274314
# 94639      ZYX  CRISPRa   -0.304185   -0.710105 -0.576270 -2.440234  0.058389
# 94644    ZZEF1  CRISPRa    0.519295    0.358665  0.451590  1.328978  0.215414
# 94649     ZZZ3  CRISPRa   -0.361215    0.145345 -0.038584 -0.468514  0.683262
#
#          Hit Hit_Type Cytokine
# 4      False      NaN     TNFa
# 9      False      NaN     TNFa
# 14     False      NaN     TNFa
# 19     False      NaN     TNFa
# 24     False      NaN     TNFa
# ...      ...      ...      ...
# 94629  False      NaN     TNFa
# 94634  False      NaN     TNFa
# 94639  False      NaN     TNFa
# 94644  False      NaN     TNFa
# 94649  False      NaN     TNFa
#
# [18930 rows x 10 columns]

# %%
# Out:
#           Gene   Screen  Donor1_LFC  Donor2_LFC       LFC    zscore       FDR  \
# 4         A1BG  CRISPRa    0.266305   -0.087442  0.190800  0.372649  0.965390
# 9         A1CF  CRISPRa    0.223835    0.189680  0.223830  0.493771  1.000000
# 14         A2M  CRISPRa    0.177685    0.204170  0.177690  0.324574  0.758835
# 19       A2ML1  CRISPRa   -0.084406    0.017370 -0.078052 -0.613245  0.645506
# 24     A3GALT2  CRISPRa   -0.060033    0.251070  0.112140  0.084199  0.623199
# ...        ...      ...         ...         ...       ...       ...       ...
# 94629   ZYG11A  CRISPRa   -0.057830    0.116976  0.077883 -0.041424  0.787891
# 94634   ZYG11B  CRISPRa    0.148973    0.401131  0.148970  0.219256  0.274314
# 94639      ZYX  CRISPRa   -0.304185   -0.710105 -0.576270 -2.440234  0.058389
# 94644    ZZEF1  CRISPRa    0.519295    0.358665  0.451590  1.328978  0.215414
# 94649     ZZZ3  CRISPRa   -0.361215    0.145345 -0.038584 -0.468514  0.683262
#
#          Hit Hit_Type Cytokine
# 4      False      NaN     TNFa
# 9      False      NaN     TNFa
# 14     False      NaN     TNFa
# 19     False      NaN     TNFa
# 24     False      NaN     TNFa
# ...      ...      ...      ...
# 94629  False      NaN     TNFa
# 94634  False      NaN     TNFa
# 94639  False      NaN     TNFa
# 94644  False      NaN     TNFa
# 94649  False      NaN     TNFa
#
# [18930 rows x 10 columns]

# %%
screen_analysis_table['Hit_Type'].value_counts()
# Out:
# Hit_Type
# Negative Regulator    313
# Positive Regulator    173
# Name: count, dtype: int64

# %% [markdown]
# # TNFa Positive Regulator sorted by LFC

# %%
screen_analysis_table[screen_analysis_table['Hit_Type'] == 'Positive Regulator'].sort_values('LFC', ascending=False).head(50)
# Out:
#           Gene   Screen  Donor1_LFC  Donor2_LFC      LFC     zscore       FDR  \
# 13374     CD28  CRISPRa    2.951000    3.283600  2.95100  10.494437  0.000146
# 88734     VAV1  CRISPRa    2.794650    3.141850  2.85250  10.133232  0.000146
# 16919     CNR2  CRISPRa    2.410700    1.824950  2.14690   7.545763  0.000146
# 57389   OTUD7B  CRISPRa    1.264495    2.237250  1.92200   6.721043  0.000146
# 20889     DEF6  CRISPRa    1.594400    2.082950  1.86320   6.505421  0.000146
# 21204   DEPDC7  CRISPRa    1.914250    1.328050  1.59070   5.506150  0.000146
# 29179    FOXD2  CRISPRa    1.862250    1.166350  1.54120   5.324631  0.000146
# 36349    HSFX2  CRISPRa    1.585000    1.350800  1.46790   5.055837  0.001036
# 42909     LCP2  CRISPRa    1.679200    1.397350  1.39740   4.797310  0.000146
# 32819    GPR84  CRISPRa    1.033845    1.643900  1.36310   4.671530  0.000146
# 84164  TNFRSF9  CRISPRa    1.404200    1.146300  1.32440   4.529615  0.000146
# 60454  PIK3AP1  CRISPRa    1.074275    1.324550  1.24090   4.223417  0.000146
# 73519  SLC16A1  CRISPRa    1.478000    0.792890  1.23900   4.216449  0.000146
# 80549    TBX21  CRISPRa    1.022025    1.320700  1.23720   4.209848  0.000146
# 46174   MAP2K6  CRISPRa    0.914805    1.364350  1.21080   4.113038  0.000146
# 57569   P2RY14  CRISPRa    1.072600    1.276150  1.17270   3.973324  0.000146
# 61099    PLCG2  CRISPRa    1.134910    1.187800  1.16380   3.940687  0.000146
# 38709     IRX4  CRISPRa    1.202750    1.099300  1.15180   3.896683  0.000146
# 90754    ZAP70  CRISPRa    0.935420    1.390350  1.14930   3.887515  0.000146
# 57384   OTUD7A  CRISPRa    1.163805    1.111650  1.11170   3.749634  0.000146
# 29369    FOXQ1  CRISPRa    1.071355    0.931075  1.06590   3.581683  0.001960
# 77649   SQSTM1  CRISPRa    1.090850    0.769485  1.06080   3.562981  0.000146
# 71959  SERINC3  CRISPRa    1.101500    0.763615  1.06060   3.562248  0.003440
# 69779    RRAS2  CRISPRa    0.874465    1.275600  1.04500   3.505042  0.000146
# 70209    RUNX3  CRISPRa    0.976370    1.040650  1.04060   3.488907  0.000146
# 32644    GPR18  CRISPRa    0.908425    1.081900  1.02350   3.426200  0.002038
# 79694     TAB3  CRISPRa    1.046155    0.958540  1.01740   3.403831  0.000146
# 29174    FOXD1  CRISPRa    0.649615    1.671350  1.01550   3.396864  0.000146
# 67414     RER1  CRISPRa    0.415215    1.123835  1.01420   3.392097  0.001960
# 24709     EMP1  CRISPRa    1.259600    0.881850  1.01220   3.384762  0.000146
# 66079     RAC2  CRISPRa    0.636780    1.166250  1.00260   3.349559  0.000619
# 88744     VAV3  CRISPRa    1.091180    0.869555  0.97321   3.241784  0.000146
# 61284  PLEKHG6  CRISPRa    1.094900    0.401214  0.96388   3.207571  0.000413
# 43514     LIN9  CRISPRa    0.816340    1.079430  0.94772   3.148311  0.004254
# 24369   ELAVL3  CRISPRa    0.781875    1.234250  0.93273   3.093342  0.000146
# 30909   GEMIN7  CRISPRa    0.923870    0.820310  0.92387   3.060852  0.000146
# 89989    WIPF1  CRISPRa    0.900990    0.922465  0.92247   3.055718  0.002038
# 2619      AKT3  CRISPRa    0.792380    0.921570  0.92157   3.052418  0.005098
# 67344     RELA  CRISPRa    1.114450    0.682975  0.91854   3.041307  0.000619
# 72364      SFN  CRISPRa    0.795865    1.090170  0.91740   3.037126  0.000845
# 32524   GPR141  CRISPRa    1.145800    0.804445  0.91132   3.014831  0.002109
# 50914     MYRF  CRISPRa    0.841080    0.902140  0.90214   2.981167  0.000146
# 60529   PIK3R6  CRISPRa    0.890575    0.907880  0.89055   2.938666  0.000146
# 37889    IL36A  CRISPRa    0.889225    0.888295  0.88922   2.933789  0.000413
# 26394  FAM129B  CRISPRa    0.555755    1.114900  0.87393   2.877720  0.011232
# 91299   ZDHHC2  CRISPRa    0.894620    0.534640  0.87258   2.872769  0.012765
# 13484     CD40  CRISPRa    1.237750    0.591695  0.86905   2.859824  0.006294
# 79284   SWAP70  CRISPRa    0.821305    0.868255  0.86826   2.856927  0.001960
# 92394   ZNF296  CRISPRa    0.823325    0.855945  0.85594   2.811749  0.021244
# 34569   HEPHL1  CRISPRa    0.652215    0.919135  0.84690   2.778599  0.001960
#
#         Hit            Hit_Type Cytokine
# 13374  True  Positive Regulator     TNFa
# 88734  True  Positive Regulator     TNFa
# 16919  True  Positive Regulator     TNFa
# 57389  True  Positive Regulator     TNFa
# 20889  True  Positive Regulator     TNFa
# 21204  True  Positive Regulator     TNFa
# 29179  True  Positive Regulator     TNFa
# 36349  True  Positive Regulator     TNFa
# 42909  True  Positive Regulator     TNFa
# 32819  True  Positive Regulator     TNFa
# 84164  True  Positive Regulator     TNFa
# 60454  True  Positive Regulator     TNFa
# 73519  True  Positive Regulator     TNFa
# 80549  True  Positive Regulator     TNFa
# 46174  True  Positive Regulator     TNFa
# 57569  True  Positive Regulator     TNFa
# 61099  True  Positive Regulator     TNFa
# 38709  True  Positive Regulator     TNFa
# 90754  True  Positive Regulator     TNFa
# 57384  True  Positive Regulator     TNFa
# 29369  True  Positive Regulator     TNFa
# 77649  True  Positive Regulator     TNFa
# 71959  True  Positive Regulator     TNFa
# 69779  True  Positive Regulator     TNFa
# 70209  True  Positive Regulator     TNFa
# 32644  True  Positive Regulator     TNFa
# 79694  True  Positive Regulator     TNFa
# 29174  True  Positive Regulator     TNFa
# 67414  True  Positive Regulator     TNFa
# 24709  True  Positive Regulator     TNFa
# 66079  True  Positive Regulator     TNFa
# 88744  True  Positive Regulator     TNFa
# 61284  True  Positive Regulator     TNFa
# 43514  True  Positive Regulator     TNFa
# 24369  True  Positive Regulator     TNFa
# 30909  True  Positive Regulator     TNFa
# 89989  True  Positive Regulator     TNFa
# 2619   True  Positive Regulator     TNFa
# 67344  True  Positive Regulator     TNFa
# 72364  True  Positive Regulator     TNFa
# 32524  True  Positive Regulator     TNFa
# 50914  True  Positive Regulator     TNFa
# 60529  True  Positive Regulator     TNFa
# 37889  True  Positive Regulator     TNFa
# 26394  True  Positive Regulator     TNFa
# 91299  True  Positive Regulator     TNFa
# 13484  True  Positive Regulator     TNFa
# 79284  True  Positive Regulator     TNFa
# 92394  True  Positive Regulator     TNFa
# 34569  True  Positive Regulator     TNFa

# %% [markdown]
# # TNFa Negative Regulator sorted by LFC

# %%
screen_analysis_table[screen_analysis_table['Hit_Type'] == 'Negative Regulator'].sort_values('LFC', ascending=True).head(50)
# Out:
#            Gene   Screen  Donor1_LFC  Donor2_LFC     LFC     zscore       FDR  \
# 46284    MAP4K1  CRISPRa   -2.977800   -3.121200 -2.9857 -11.275732  0.000087
# 42669      LAT2  CRISPRa   -2.719400   -3.354000 -2.7353 -10.357503  0.000087
# 45414       LYN  CRISPRa   -1.723000   -2.746550 -2.6801 -10.155082  0.000087
# 32999      GRAP  CRISPRa   -2.205550   -2.730950 -2.3893  -9.088704  0.000087
# 4794    ARHGDIB  CRISPRa   -2.112650   -1.882950 -2.1127  -8.074398  0.000087
# 42829       LCK  CRISPRa   -1.240155   -2.984700 -2.1126  -8.074032  0.000087
# 60694     PITX1  CRISPRa   -2.092750   -2.133500 -2.0928  -8.001424  0.000087
# 13344     CD244  CRISPRa   -1.697950   -2.703100 -2.0793  -7.951919  0.000087
# 73324      SLA2  CRISPRa   -1.966850   -2.029900 -2.0299  -7.770767  0.000087
# 37539     IKZF3  CRISPRa   -1.900400   -2.347400 -1.9660  -7.536442  0.000087
# 38244    INPPL1  CRISPRa   -1.882050   -2.018300 -1.9458  -7.462368  0.000087
# 50224      MUC1  CRISPRa   -2.044200   -1.904000 -1.9040  -7.309085  0.000087
# 39054     ITPKA  CRISPRa   -1.331485   -2.199450 -1.8502  -7.111798  0.000087
# 84579       TOX  CRISPRa   -1.647200   -1.687250 -1.6664  -6.437794  0.000087
# 65089    PTPN12  CRISPRa   -1.621150   -1.589250 -1.6212  -6.272044  0.000087
# 29339     FOXO4  CRISPRa   -1.570500   -1.882445 -1.5705  -6.086124  0.000087
# 44689    LRRC25  CRISPRa   -1.565550   -1.704850 -1.5656  -6.068156  0.000087
# 90054      WNK4  CRISPRa   -1.094660   -1.540000 -1.4944  -5.807062  0.000087
# 43444     LIME1  CRISPRa   -1.746300   -1.396100 -1.4784  -5.748389  0.000087
# 14359   CEACAM1  CRISPRa   -1.334500   -1.837800 -1.4724  -5.726387  0.000087
# 30494     GATA3  CRISPRa   -1.687700   -0.924820 -1.4625  -5.690083  0.000087
# 80744    TCF7L1  CRISPRa   -1.006455   -1.527900 -1.4103  -5.498663  0.000087
# 76559     SOX18  CRISPRa   -1.407050   -1.302110 -1.4071  -5.486929  0.000087
# 50269     MUC21  CRISPRa   -1.370650   -1.772000 -1.3888  -5.419822  0.000087
# 28184     FCRL5  CRISPRa   -0.922160   -1.442350 -1.3593  -5.311644  0.000087
# 33029      GRB2  CRISPRa   -1.314815   -1.309865 -1.3099  -5.130491  0.000087
# 65149     PTPN6  CRISPRa   -1.175700   -1.402000 -1.2912  -5.061918  0.000087
# 6814   B4GALNT3  CRISPRa   -0.509200   -1.829050 -1.2772  -5.010579  0.000087
# 1494      ADCY1  CRISPRa   -1.306450   -1.051860 -1.2729  -4.994811  0.000087
# 65174     PTPRC  CRISPRa   -1.334550   -1.262950 -1.2629  -4.958140  0.000087
# 91469     ZFP36  CRISPRa   -1.223035   -1.246350 -1.2463  -4.897267  0.000087
# 75814     SMOC2  CRISPRa   -0.872050   -1.515890 -1.2252  -4.819892  0.000087
# 51014     NAA15  CRISPRa   -1.287050   -0.883915 -1.2090  -4.760486  0.003894
# 24964     EPB41  CRISPRa   -1.129035   -1.543850 -1.1934  -4.703280  0.000087
# 75469     SMAGP  CRISPRa   -1.182600   -1.043250 -1.1782  -4.647541  0.000087
# 29229     FOXF1  CRISPRa   -1.176100   -1.232970 -1.1761  -4.639840  0.000087
# 60464   PIK3C2B  CRISPRa   -1.101900   -1.290450 -1.1659  -4.602436  0.000087
# 76599      SOX7  CRISPRa   -1.150350   -1.235650 -1.1635  -4.593636  0.000087
# 77329       SPN  CRISPRa   -1.578000   -0.808870 -1.1522  -4.552198  0.000087
# 42684      LAX1  CRISPRa   -1.093945   -1.147300 -1.1473  -4.534229  0.000087
# 46304    MAP4K5  CRISPRa   -0.830810   -1.243350 -1.1365  -4.494625  0.000087
# 13304     CD200  CRISPRa   -0.916310   -1.142600 -1.1356  -4.491325  0.000087
# 6774     B3GNT5  CRISPRa   -0.726065   -1.403800 -1.1324  -4.479590  0.000240
# 29149     FOXA3  CRISPRa   -1.203300   -0.832245 -1.1238  -4.448054  0.000665
# 30754    GCSAML  CRISPRa   -1.121850   -1.052000 -1.1219  -4.441086  0.000665
# 44359     LPAR5  CRISPRa   -0.834965   -1.411400 -1.1161  -4.419817  0.000087
# 36629      HTR7  CRISPRa   -0.500845   -1.329500 -1.1128  -4.407716  0.001870
# 58144    PARP12  CRISPRa   -1.100850   -0.819462 -1.1009  -4.364078  0.001796
# 78424    STAT5A  CRISPRa   -0.982800   -1.095750 -1.0958  -4.345376  0.001423
# 79509     SYPL1  CRISPRa   -0.827570   -1.131500 -1.0864  -4.310906  0.000240
#
#         Hit            Hit_Type Cytokine
# 46284  True  Negative Regulator     TNFa
# 42669  True  Negative Regulator     TNFa
# 45414  True  Negative Regulator     TNFa
# 32999  True  Negative Regulator     TNFa
# 4794   True  Negative Regulator     TNFa
# 42829  True  Negative Regulator     TNFa
# 60694  True  Negative Regulator     TNFa
# 13344  True  Negative Regulator     TNFa
# 73324  True  Negative Regulator     TNFa
# 37539  True  Negative Regulator     TNFa
# 38244  True  Negative Regulator     TNFa
# 50224  True  Negative Regulator     TNFa
# 39054  True  Negative Regulator     TNFa
# 84579  True  Negative Regulator     TNFa
# 65089  True  Negative Regulator     TNFa
# 29339  True  Negative Regulator     TNFa
# 44689  True  Negative Regulator     TNFa
# 90054  True  Negative Regulator     TNFa
# 43444  True  Negative Regulator     TNFa
# 14359  True  Negative Regulator     TNFa
# 30494  True  Negative Regulator     TNFa
# 80744  True  Negative Regulator     TNFa
# 76559  True  Negative Regulator     TNFa
# 50269  True  Negative Regulator     TNFa
# 28184  True  Negative Regulator     TNFa
# 33029  True  Negative Regulator     TNFa
# 65149  True  Negative Regulator     TNFa
# 6814   True  Negative Regulator     TNFa
# 1494   True  Negative Regulator     TNFa
# 65174  True  Negative Regulator     TNFa
# 91469  True  Negative Regulator     TNFa
# 75814  True  Negative Regulator     TNFa
# 51014  True  Negative Regulator     TNFa
# 24964  True  Negative Regulator     TNFa
# 75469  True  Negative Regulator     TNFa
# 29229  True  Negative Regulator     TNFa
# 60464  True  Negative Regulator     TNFa
# 76599  True  Negative Regulator     TNFa
# 77329  True  Negative Regulator     TNFa
# 42684  True  Negative Regulator     TNFa
# 46304  True  Negative Regulator     TNFa
# 13304  True  Negative Regulator     TNFa
# 6774   True  Negative Regulator     TNFa
# 29149  True  Negative Regulator     TNFa
# 30754  True  Negative Regulator     TNFa
# 44359  True  Negative Regulator     TNFa
# 36629  True  Negative Regulator     TNFa
# 58144  True  Negative Regulator     TNFa
# 78424  True  Negative Regulator     TNFa
# 79509  True  Negative Regulator     TNFa

# %%
hits_translate = {
    'Negative Regulator': 'Positive Hit',
    'Positive Regulator': 'Negative Hit'
}
screen_analysis_table['Hit_Type'] = screen_analysis_table['Hit_Type'].apply(hits_translate.get)

# %%
top_n = 10
fig_1 = plot_donors_scatter(
    screen_analysis_table,
    'Donor 15, LFC',
    'Donor 16, LFC',
    f'{cell_type}-{cytokine}'
);

# %%
fig_2 = plot_volcano(
    screen_analysis_table,
    x_label='LFC ' + '$'+f'{cytokine}'+'^{hi}/TNFa^{low}$',
    y_label='$-Log_{10}(FDR)$',
    plot_title=f'{cell_type}-{cytokine}',
    eps=1e-6,
    # top_10_low=top_10_low,
    # top_10_high=top_10_high,
    fig_size=(10, 8)
)
# Out:
# Upregulated:
# ['CD28', 'VAV1', 'CNR2', 'OTUD7B', 'DEF6', 'DEPDC7', 'FOXD2', 'HSFX2', 'LCP2', 'GPR84']
# Downregulated:
# ['MAP4K1', 'LAT2', 'LYN', 'GRAP', 'ARHGDIB', 'LCK', 'PITX1', 'CD244', 'SLA2', 'IKZF3']
